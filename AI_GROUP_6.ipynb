# %% [markdown]
# <a href="https://colab.research.google.com/github/lawalabdurrashid123-dev/AI-KELOMPOK6/blob/main/AI_GROUP_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Menu & Nutrition Knowledge Base

kb = [
    ("Rice", "contains", "Carbohydrates"),
    ("Chicken", "contains", "Protein")
]

print("=== Knowledge Base ===")
for s, p, o in kb:
    print(f"{s} {p} {o}")

print("\n=== Query Result ===")
for s, p, o in kb:
    if o == "Protein":
        print(f"{s} contains Protein")
# Out:
# === Knowledge Base ===
# Rice contains Carbohydrates
# Chicken contains Protein
#
# === Query Result ===
# Chicken contains Protein
